# %% [markdown]
# ## Index
#
# [1 Import Packages](#1)<br>
# [2 Load Dataset](#2)<br>
# [3 Data Preprocessing](#3)<br>
# [4 Train Network](#4)<br>
#     <ul>
#         <li>[4.1 Basic approach](#41)</li>
#         <li>[4.2 Convolutional approach ](#42)</li>
#     </ul>
# [5. Evaluation of the model](#5)<br>
#     <ul>
#         <li>[5.1 Confusion matrix and metrics](#51)</li>
#     </ul>
# [6. Save and load the model](#6)<br>
# [7. References](#7)<br>

# %% [markdown]
# <a id='1'></a>
# <div class="alert alert-block alert-danger">
# <h2>1 Import Packages</h2>
# </div>

# %%
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['TFF_CPP_MIN_LOG_LEVEL'] = '2'    # ignore information messages

import cv2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import Sequential, Input, Model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import relu
from tensorflow.keras.models import load_model

import tensorflow_datasets as tfds
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
## hide progress bar while executing
# tfds.disable.progress_bar()

# %%
# tensorflow built-in datasets
# tfds.list_builders()

# %% [markdown]
# <a id='2'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     2 Load Dataset
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Get information on the Data</strong>
# </div>

# %%
builder = tfds.builder('rock_paper_scissors')

info = builder.info
info
# Out:
# tfds.core.DatasetInfo(
#     name='rock_paper_scissors',
#     full_name='rock_paper_scissors/3.0.0',
#     description="""
#     Images of hands playing rock, paper, scissor game.
#     """,
#     homepage='http://laurencemoroney.com/rock-paper-scissors-dataset',
#     data_path='/Users/onurkaraguler/tensorflow_datasets/rock_paper_scissors/3.0.0',
#     download_size=219.53 MiB,
#     dataset_size=219.23 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(300, 300, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=3),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=372, num_shards=1>,
#         'train': <SplitInfo num_examples=2520, num_shards=2>,
#     },
#     citation="""@ONLINE {rps,
#     author = "Laurence Moroney",
#     title = "Rock, Paper, Scissors Dataset",
#     month = "feb",
#     year = "2019",
#     url = "http://laurencemoroney.com/rock-paper-scissors-dataset"
#     }""",
# )

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Load datasets from tensorflow_datasets</strong>
# </div>

# %%
train_images, train_labels = tfds.load(name="rock_paper_scissors", split='train', batch_size=-1, as_supervised=True)
test_images, test_labels = tfds.load(name="rock_paper_scissors", split='test', batch_size=-1, as_supervised=True)
# Out:
# 2021-08-06 00:57:19.388469: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2021-08-06 00:57:19.388570: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2021-08-06 00:57:19.412073: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:176] None of the MLIR Optimization Passes are enabled (registered 2)
# 2021-08-06 00:57:19.412288: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Metal device set to: Apple M1

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (2520, 300, 300, 3)
# (2520,)
# (372, 300, 300, 3)
# (372,)

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Plot some images to verify the data</strong>
# </div>

# %%
class_names = ['rock', 'paper', 'scissor']
plt.figure(figsize=(8,8))
for i in range(16):
    plt.subplot(4,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# fig = tfds.show_examples(ds_train, info)

# %% [markdown]
# <a id='3'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     3 Data Preprocessing
#     </h2>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Resize images</strong>
# </div>

# %%
def resize_images(img):
    img_height = img_width = 28
    img = cv2.resize(np.float32(img), (img_height, img_width))

    # color channel must be for Convolutional Neural Network in Keras. 1 represents gray color.
    img = np.reshape(img[:,:,0], (img_height, img_width, 1))
    return img

# %%
# convert list to numpy array
train_images = np.array([resize_images(img) for img in train_images])
test_images = np.array([resize_images(img) for img in test_images])

print(train_images.shape)
print(test_images.shape)
# Out:
# (2520, 28, 28, 1)
# (372, 28, 28, 1)

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Plot some of the reshaped images</strong>
# </div>

# %%
import matplotlib.pyplot as plt
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(array_to_img(train_images[i]))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Normalisation</strong>
# </div>

# %%
# Normalize pixel values to be between 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# %%
train_images[0].shape
# Out:
# (28, 28, 1)

# %%
test_images.dtype
# Out:
# dtype('float32')

# %% [markdown]
# <a id='4'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     4 Train Network
#     </h2>
# </div>

# %%
def plot_losses(acc, val_acc, loss, val_loss):
    
    epochs = range(len(acc))

    fig, axes = plt.subplots(1, 2, figsize=(10, 4))
    
    # accuracy
    axes[0].plot(epochs, acc, 'b', color='green', linewidth=2, label='Training accuracy')
    axes[0].plot(epochs, val_acc, color='blue', linewidth=2, label='Validation accuracy')
    axes[0].fill_between(epochs, acc, val_acc, color='red', alpha=0.3)
    axes[0].set_title('Training and validation accuracy', color='red', size=14)
    axes[0].set_xlabel('Epochs', size=12)
    axes[0].set_ylabel('Accuracy', size=12)
    axes[0].legend(title='Accuracy', loc='lower right')
    
    # loss
    axes[1].plot(epochs, loss, 'b', color='green', linewidth=2, label='Training loss')
    axes[1].plot(epochs, val_loss, 'b', color='blue', linewidth=2, label='Validation loss')
    axes[1].fill_between(epochs, loss, val_loss, color='red', alpha=0.3)
    axes[1].set_title('Training and validation loss', color='red', size=14)
    axes[1].set_xlabel('Epochs', size=12)
    axes[1].set_ylabel('Loss', size=12)
    axes[1].legend(title='Loss', loc='lower right')
    
    fig.tight_layout()
    plt.show()

# %% [markdown]
# <a id='41'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         4.1 Sequential model
#    </h3>
# </div>

# %% [markdown]
# <div>
# <img src="https://miro.medium.com/max/567/1*ytBUCmhkAucJ5imsNfAyfQ.png" width="300">
# </div>

# %%
model = Sequential([
    Flatten(),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    # 3 -> (rock, paper, scissors)
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
             loss=SparseCategoricalCrossentropy(),
             metrics=['accuracy'])

# %%
# %%time
history = model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=10, 
                    batch_size=32)
# Out:
# Epoch 1/10
# 19/79 [======>.......................] - ETA: 0s - loss: 1.1384 - accuracy: 0.3832
# 2021-08-06 00:57:21.722137: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 1s 7ms/step - loss: 1.0259 - accuracy: 0.4714 - val_loss: 1.0191 - val_accuracy: 0.5215
# Epoch 2/10
# 21/79 [======>.......................] - ETA: 0s - loss: 0.7477 - accuracy: 0.6964
# 2021-08-06 00:57:22.291523: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 0s 6ms/step - loss: 0.6728 - accuracy: 0.7115 - val_loss: 1.5033 - val_accuracy: 0.4597
# Epoch 3/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.5652 - accuracy: 0.7865 - val_loss: 1.1717 - val_accuracy: 0.5538
# Epoch 4/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.3862 - accuracy: 0.8607 - val_loss: 2.5240 - val_accuracy: 0.4409
# Epoch 5/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.4094 - accuracy: 0.8476 - val_loss: 2.1785 - val_accuracy: 0.4543
# Epoch 6/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.2958 - accuracy: 0.8960 - val_loss: 1.6984 - val_accuracy: 0.4516
# Epoch 7/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9583 - val_loss: 2.1335 - val_accuracy: 0.5726
# Epoch 8/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1582 - accuracy: 0.9500 - val_loss: 2.3686 - val_accuracy: 0.5081
# Epoch 9/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9591 - val_loss: 1.9315 - val_accuracy: 0.6022
# Epoch 10/10
# 79/79 [==============================] - 0s 6ms/step - loss: 0.0954 - accuracy: 0.9667 - val_loss: 2.4383 - val_accuracy: 0.5753
# CPU times: user 4.08 s, sys: 3.32 s, total: 7.41 s
# Wall time: 4.83 s

# %% [markdown]
# - accuracy for the training set is 97%, but 52% for the test
# - overfitting problem

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Plot some of the reshaped images</strong>
# </div>

# %%
for i in history.history:
    print(i)
# Out:
# loss
# accuracy
# val_loss
# val_accuracy

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plot_losses(acc, val_acc, loss, val_loss)

# %% [markdown]
# <a id='42'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         4.2 Convolutional model
#    </h3>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image.png" width="200">
# </div>

# %%
inputs = Input(shape=(28, 28, 1))
x = Conv2D(32, 3)(inputs)
x = BatchNormalization()(x)
x = relu(x)
x = MaxPooling2D()(x)
x = Conv2D(64, 3)(x)
x = BatchNormalization()(x)
x = relu(x)
x = MaxPooling2D()(x)
x = Conv2D(128, 3)(x)
x = BatchNormalization()(x)
x = relu(x)
x = Flatten()(x)
x = Dense(64, activation="relu")(x)
outputs = Dense(3, activation="sigmoid")(x)
model = Model(inputs=inputs, outputs=outputs)

##################

model.compile(optimizer='adam',
             loss=SparseCategoricalCrossentropy(),
             metrics=['accuracy'])

# %%
# the complete architecture of your model:
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 26, 26, 32)        128
# _________________________________________________________________
# tf.nn.relu (TFOpLambda)      (None, 26, 26, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# tf.nn.relu_1 (TFOpLambda)    (None, 11, 11, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# tf.nn.relu_2 (TFOpLambda)    (None, 3, 3, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1152)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                73792
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 167,555
# Trainable params: 167,107
# Non-trainable params: 448
# _________________________________________________________________

# %%
# %%time
history = model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=30, 
                    batch_size=16)
# Out:
# Epoch 1/30
#   7/158 [>.............................] - ETA: 1s - loss: 0.8842 - accuracy: 0.5804
# 2021-08-06 00:57:26.727692: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0962 - accuracy: 0.9675 - val_loss: 1.0720 - val_accuracy: 0.4570
# Epoch 2/30
#   1/158 [..............................] - ETA: 1s - loss: 0.0010 - accuracy: 1.0000
# 2021-08-06 00:57:28.287907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 158/158 [==============================] - 1s 9ms/step - loss: 9.3154e-04 - accuracy: 1.0000 - val_loss: 1.2793 - val_accuracy: 0.4220
# Epoch 3/30
# 158/158 [==============================] - 1s 9ms/step - loss: 3.2231e-04 - accuracy: 1.0000 - val_loss: 1.1167 - val_accuracy: 0.5968
# Epoch 4/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.6755e-04 - accuracy: 1.0000 - val_loss: 0.8708 - val_accuracy: 0.6801
# Epoch 5/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.1271e-04 - accuracy: 1.0000 - val_loss: 0.7618 - val_accuracy: 0.7097
# Epoch 6/30
# 158/158 [==============================] - 1s 9ms/step - loss: 7.9402e-05 - accuracy: 1.0000 - val_loss: 0.7642 - val_accuracy: 0.7124
# Epoch 7/30
# 158/158 [==============================] - 1s 9ms/step - loss: 5.7457e-05 - accuracy: 1.0000 - val_loss: 0.7258 - val_accuracy: 0.7231
# Epoch 8/30
# 158/158 [==============================] - 1s 9ms/step - loss: 5.0723e-05 - accuracy: 1.0000 - val_loss: 0.7560 - val_accuracy: 0.7231
# Epoch 9/30
# 158/158 [==============================] - 1s 9ms/step - loss: 4.0332e-05 - accuracy: 1.0000 - val_loss: 0.7043 - val_accuracy: 0.7500
# Epoch 10/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.9161e-05 - accuracy: 1.0000 - val_loss: 0.7303 - val_accuracy: 0.7312
# Epoch 11/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.3431e-05 - accuracy: 1.0000 - val_loss: 0.7597 - val_accuracy: 0.7285
# Epoch 12/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.1268e-05 - accuracy: 1.0000 - val_loss: 0.7463 - val_accuracy: 0.7339
# Epoch 13/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.7226e-05 - accuracy: 1.0000 - val_loss: 0.7825 - val_accuracy: 0.7312
# Epoch 14/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.4593e-05 - accuracy: 1.0000 - val_loss: 0.7586 - val_accuracy: 0.7285
# Epoch 15/30
# 158/158 [==============================] - 1s 9ms/step - loss: 9.6796e-06 - accuracy: 1.0000 - val_loss: 0.7522 - val_accuracy: 0.7339
# Epoch 16/30
# 158/158 [==============================] - 1s 9ms/step - loss: 8.9497e-06 - accuracy: 1.0000 - val_loss: 0.7414 - val_accuracy: 0.7392
# Epoch 17/30
# 158/158 [==============================] - 1s 9ms/step - loss: 9.3014e-06 - accuracy: 1.0000 - val_loss: 0.7275 - val_accuracy: 0.7446
# Epoch 18/30
# 158/158 [==============================] - 1s 9ms/step - loss: 5.7534e-06 - accuracy: 1.0000 - val_loss: 0.7630 - val_accuracy: 0.7339
# Epoch 19/30
# 158/158 [==============================] - 1s 9ms/step - loss: 6.2308e-06 - accuracy: 1.0000 - val_loss: 0.7715 - val_accuracy: 0.7392
# Epoch 20/30
# 158/158 [==============================] - 1s 9ms/step - loss: 6.0508e-06 - accuracy: 1.0000 - val_loss: 0.7704 - val_accuracy: 0.7392
# Epoch 21/30
# 158/158 [==============================] - 1s 9ms/step - loss: 4.4585e-06 - accuracy: 1.0000 - val_loss: 0.7888 - val_accuracy: 0.7366
# Epoch 22/30
# 158/158 [==============================] - 1s 9ms/step - loss: 3.8817e-06 - accuracy: 1.0000 - val_loss: 0.7985 - val_accuracy: 0.7419
# Epoch 23/30
# 158/158 [==============================] - 1s 9ms/step - loss: 4.5437e-06 - accuracy: 1.0000 - val_loss: 0.7915 - val_accuracy: 0.7392
# Epoch 24/30
# 158/158 [==============================] - 1s 9ms/step - loss: 4.7755e-06 - accuracy: 1.0000 - val_loss: 0.7870 - val_accuracy: 0.7392
# Epoch 25/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.8522e-06 - accuracy: 1.0000 - val_loss: 0.7836 - val_accuracy: 0.7419
# Epoch 26/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.4630e-06 - accuracy: 1.0000 - val_loss: 0.7883 - val_accuracy: 0.7446
# Epoch 27/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.9518e-06 - accuracy: 1.0000 - val_loss: 0.8488 - val_accuracy: 0.7392
# Epoch 28/30
# 158/158 [==============================] - 1s 9ms/step - loss: 2.0284e-06 - accuracy: 1.0000 - val_loss: 0.8398 - val_accuracy: 0.7419
# Epoch 29/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.8417e-06 - accuracy: 1.0000 - val_loss: 0.8184 - val_accuracy: 0.7419
# Epoch 30/30
# 158/158 [==============================] - 1s 9ms/step - loss: 1.8221e-06 - accuracy: 1.0000 - val_loss: 0.7915 - val_accuracy: 0.7473
# CPU times: user 30.3 s, sys: 24.5 s, total: 54.8 s
# Wall time: 43.8 s

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Plot some of the reshaped images</strong>
# </div>

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plot_losses(acc, val_acc, loss, val_loss)

# %%
# %%time
model = Sequential([
    Conv2D(32, 3, activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Conv2D(64, 3, activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Conv2D(128, 3, activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.5),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(3, activation='sigmoid')
])

##################

model.compile(optimizer='adam',
             loss=SparseCategoricalCrossentropy(),
             metrics=['accuracy'])
# Out:
# CPU times: user 84.2 ms, sys: 15.4 ms, total: 99.6 ms
# Wall time: 34.1 ms

# %%
# the complete architecture of your model:
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 64)        256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 195
# =================================================================
# Total params: 102,019
# Trainable params: 101,571
# Non-trainable params: 448
# _________________________________________________________________

# %%
# %%time
history = model.fit(train_images, train_labels, validation_data=(test_images, test_labels), epochs=30, 
                    batch_size=16)
# Out:
# Epoch 1/30
#  12/158 [=>............................] - ETA: 1s - loss: 1.8164 - accuracy: 0.3958
# 2021-08-06 00:58:10.660389: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 158/158 [==============================] - 2s 10ms/step - loss: 0.8767 - accuracy: 0.6440 - val_loss: 2.9910 - val_accuracy: 0.3333
# Epoch 2/30
#   7/158 [>.............................] - ETA: 1s - loss: 0.4851 - accuracy: 0.7679
# 2021-08-06 00:58:12.221802: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 158/158 [==============================] - 1s 9ms/step - loss: 0.4135 - accuracy: 0.8337 - val_loss: 4.2025 - val_accuracy: 0.3333
# Epoch 3/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.2708 - accuracy: 0.8984 - val_loss: 3.8564 - val_accuracy: 0.3333
# Epoch 4/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1722 - accuracy: 0.9425 - val_loss: 1.1796 - val_accuracy: 0.6935
# Epoch 5/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1436 - accuracy: 0.9452 - val_loss: 0.6253 - val_accuracy: 0.7688
# Epoch 6/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.1076 - accuracy: 0.9647 - val_loss: 1.7171 - val_accuracy: 0.6290
# Epoch 7/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.1020 - accuracy: 0.9643 - val_loss: 0.3421 - val_accuracy: 0.8495
# Epoch 8/30
# 158/158 [==============================] - 2s 9ms/step - loss: 0.0722 - accuracy: 0.9730 - val_loss: 0.4640 - val_accuracy: 0.8306
# Epoch 9/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0502 - accuracy: 0.9837 - val_loss: 1.2777 - val_accuracy: 0.6855
# Epoch 10/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0500 - accuracy: 0.9845 - val_loss: 0.3572 - val_accuracy: 0.8710
# Epoch 11/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0515 - accuracy: 0.9825 - val_loss: 0.3469 - val_accuracy: 0.8602
# Epoch 12/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0339 - accuracy: 0.9885 - val_loss: 0.3603 - val_accuracy: 0.8737
# Epoch 13/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0279 - accuracy: 0.9929 - val_loss: 0.3128 - val_accuracy: 0.8468
# Epoch 14/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0305 - accuracy: 0.9921 - val_loss: 0.5482 - val_accuracy: 0.8091
# Epoch 15/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0370 - accuracy: 0.9913 - val_loss: 0.4168 - val_accuracy: 0.8575
# Epoch 16/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0274 - accuracy: 0.9921 - val_loss: 0.3755 - val_accuracy: 0.8656
# Epoch 17/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0203 - accuracy: 0.9933 - val_loss: 1.8866 - val_accuracy: 0.6290
# Epoch 18/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0330 - accuracy: 0.9901 - val_loss: 0.5482 - val_accuracy: 0.7608
# Epoch 19/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0290 - accuracy: 0.9901 - val_loss: 0.8901 - val_accuracy: 0.7231
# Epoch 20/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0293 - accuracy: 0.9881 - val_loss: 1.1186 - val_accuracy: 0.7151
# Epoch 21/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0220 - accuracy: 0.9909 - val_loss: 1.4602 - val_accuracy: 0.6828
# Epoch 22/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0293 - accuracy: 0.9905 - val_loss: 0.5116 - val_accuracy: 0.8253
# Epoch 23/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0147 - accuracy: 0.9944 - val_loss: 0.4184 - val_accuracy: 0.8817
# Epoch 24/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0114 - accuracy: 0.9956 - val_loss: 2.0345 - val_accuracy: 0.7231
# Epoch 25/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0226 - accuracy: 0.9933 - val_loss: 1.1816 - val_accuracy: 0.7204
# Epoch 26/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.4378 - val_accuracy: 0.8253
# Epoch 27/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 1.3510 - val_accuracy: 0.7796
# Epoch 28/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0139 - accuracy: 0.9940 - val_loss: 1.8537 - val_accuracy: 0.7177
# Epoch 29/30
# 158/158 [==============================] - 2s 10ms/step - loss: 0.0127 - accuracy: 0.9940 - val_loss: 0.4118 - val_accuracy: 0.9059
# Epoch 30/30
# 158/158 [==============================] - 1s 9ms/step - loss: 0.0196 - accuracy: 0.9948 - val_loss: 1.1665 - val_accuracy: 0.6989
# CPU times: user 34.6 s, sys: 27 s, total: 1min 1s
# Wall time: 45.5 s

# %% [markdown]
# <div class="alert alert-block alert-success">
#         <strong>Plot some of the reshaped images</strong>
# </div>

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plot_losses(acc, val_acc, loss, val_loss)

# %% [markdown]
# <a id='5'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     5 Evaluation of the model
#     </h2>
# </div>

# %% [markdown]
# <a id='51'></a>
# <div class="alert alert-block alert-info">
#    <h3>
#         5.1 Confusion matrix and metrics
#    </h3>
# </div>

# %% [markdown]
# <div>
# <img src="attachment:image-2.png" width="300">
# </div>

# %%
import math

def confusion_matrix_metrics(TP, FP, FN, TN):
    # Sensitivity, hit rate, recall, or true positive rate
    TPR = round(TP / (TP + FN), 2)
    # Specificity, selectivity or true negative rate (TNR)
    TNR = round(TN / (TN + FP), 2)

    # accuracy (ACC)
    ACC = round((TP + TN) / (TP + TN + FP + FN), 2)
    # balanced accuracy (BA)
    BA = round((TPR + TNR) / 2, 2)

    # Precision or positive predictive value
    PPV = round(TP / (TP + FP), 2)
    # negative predictive value (NPV)
    NPV = round(TN / (TN + FN), 2)
    # false discovery rate (FDR)
    FDR = round(1 - PPV, 2)
    # false omission rate (FOR)
    FOR = round(1 - NPV, 2)

    # prevalence threshold (PT)
    PT = round((math.sqrt(TPR*(1 - TNR)) + TNR - 1)/(TPR + TNR - 1), 2)
    # F1 score
    F1 = round(2*TP / (2*TP + FP + FN), 2)
    # Matthews correlation coefficient (MCC) or phi coefficient
    MCC = round(((TP*TN) - (FP*FN)) / math.sqrt((TP + FP)*(TP + FN)*(TN + FP)*(TN + FN)), 2)

    # False positive rate or False alarm rate
    FPR = round(FP / (FP + TN), 2)
    # False negative rate or Miss Rate
    FNR = round(FN / (FN + TP), 2)
    
    return TPR, TNR, ACC, BA, PPV, NPV, FDR, FOR, PT, F1, MCC, FPR, FNR

# %%
def TP_FP_TN_FN_func(cm, dataframe):
    df_cm = pd.DataFrame(cm)
    TP = []
    FN = []
    TN = []
    FP = []
    for i in range(len(df_cm)):
        for j in range(len(df_cm.columns)):
            if i == j:
                # TP
                TP.append(df_cm.iloc[i,j])
                # FN
                df_FN = df_cm.drop(i, axis=0)
                FN_list = [row for row in range(len(df_cm)) if row != i]
                df_FN = df_FN.drop(FN_list, axis=1)
                FN.append(df_FN.sum().sum())
                # TN
                df_TN = df_cm.drop(i, axis=1)
                df_TN = df_TN.drop(i, axis=0)
                TN.append(df_TN.sum().sum())
                # FP
                df_FP = df_cm.drop(i, axis=1)
                FP_list = [row for row in range(len(df_cm)) if row != i]
                df_FP = df_FP.drop(FP_list, axis=0)
                FP.append(df_FP.sum().sum())
                
    metrics_list = []
    for i in range(len(TP)):
        # get the metric values from the confusion_matrix_metrics function
        (TPR, TNR, ACC, BA, PPV, NPV, FDR, FOR, PT, 
         F1, MCC, FPR, FNR) = confusion_matrix_metrics(TP[i], FP[i], FN[i], TN[i])
        metrics_list.append([TPR, TNR, ACC, BA, PPV, NPV, FDR, FOR, PT, F1, MCC, FPR, FNR])
    metrics_cols = ['True Positive Rate', 'True Negative Rate', 'Accuracy', 'Balanced Accuracy', 'Precision', 
                  'Negative Predictive Value', 'False Discovery Rate', 'False Omission Rate', 
                  'Prevalence Threshold', 'F1 Score', 'Matthews Correlation Coefficient', 
                  'False positive rate', 'False Negative Rate']
    
    # create a dataframe with multi-column
    l=[(dataframe, 'rock'),  (dataframe, 'paper'), (dataframe,'scissor')]
    df_cm_metrics = pd.DataFrame(metrics_list, columns=metrics_cols, index=l).T
    df_cm_metrics.columns = pd.MultiIndex.from_tuples(df_cm_metrics.columns, names=['Dataset','Metrics'])
    
    return df_cm_metrics

# %%
from sklearn.metrics import confusion_matrix

def confusion_matrix_func(model, train_images, test_images, train_labels, test_labels):
    
    y_train_predicted = model.predict(train_images)
    y_test_predicted = model.predict(test_images)
    
    y_train_predicted_labels = [np.argmax(i) for i in y_train_predicted]
    y_test_predicted_labels = [np.argmax(i) for i in y_test_predicted]
    
    cm = confusion_matrix(train_labels, y_train_predicted_labels).T
    cm_test = confusion_matrix(test_labels, y_test_predicted_labels).T

    
    fig, axes = plt.subplots(1, 2, figsize=(8, 4))

    # Plot the heatmap
    im = axes[0].imshow(cm, interpolation='nearest', cmap='Reds', aspect='auto')
    # show all ticks
    axes[0].set_xticks(np.arange(len(cm.tolist())))
    axes[0].set_yticks(np.arange(len(cm.tolist())))
    thresh = cm.max() / 1.5
    # Loop over data dimensions and create text annotations.
    for i in range(len(cm.tolist())):
        for j in range(len(cm.tolist())):
            text = axes[0].text(j, i, cm.tolist()[i][j],
                           ha="center", va="center", size=16,
                           color="white" if cm[i, j] > thresh else "black")
    # Let the horizontal axes labeling appear on top.
    axes[0].xaxis.set_ticks_position('top')
    axes[0].xaxis.set_label_position('top')
    axes[0].set_xlabel('Actual value', size=16)
    axes[0].set_ylabel('Predicted value', size=16)
    axes[0].set_title("Train", fontsize=20)
    
    # Plot the heatmap
    im = axes[1].imshow(cm_test, interpolation='nearest', cmap='Reds', aspect='auto')
    # show all ticks
    axes[1].set_xticks(np.arange(len(cm_test.tolist())))
    axes[1].set_yticks(np.arange(len(cm_test.tolist())))
    thresh = cm_test.max() / 1.5
    # Loop over data dimensions and create text annotations.
    for i in range(len(cm_test.tolist())):
        for j in range(len(cm_test.tolist())):
            text = axes[1].text(j, i, cm_test.tolist()[i][j],
                           ha="center", va="center", size=16,
                           color="white" if cm[i, j] > thresh else "black")
    # Let the horizontal axes labeling appear on top.
    axes[1].xaxis.set_ticks_position('top')
    axes[1].xaxis.set_label_position('top')
    axes[1].set_xlabel('Actual value', size=16)
    axes[1].set_title("Test", fontsize=20)

    fig.tight_layout()
    fig.show()
    
    # get the metric values as a dataframe
    df_cm_metrics = TP_FP_TN_FN_func(cm, 'Train')
    df_cm_test_metrics = TP_FP_TN_FN_func(cm_test, 'Test')
    
    return df_cm_metrics, df_cm_test_metrics

# %%
df_cm_metrics, df_cm_test_metrics = confusion_matrix_func(model, train_images, test_images, train_labels, test_labels)
# Out:
# 2021-08-06 00:58:56.723772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
pd.concat([df_cm_metrics, df_cm_test_metrics], axis=1)
# Out:
# Dataset                          Train                Test
# Metrics                           rock paper scissor  rock paper scissor
# True Positive Rate                 1.0  1.00    0.98  1.00  0.65    0.44
# True Negative Rate                 1.0  0.99    1.00  0.76  0.79    0.99
# Accuracy                           1.0  0.99    0.99  0.84  0.75    0.81
# Balanced Accuracy                  1.0  1.00    0.99  0.88  0.72    0.72
# Precision                          1.0  0.98    1.00  0.68  0.61    0.96
# Negative Predictive Value          1.0  1.00    0.99  1.00  0.82    0.78
# False Discovery Rate               0.0  0.02    0.00  0.32  0.39    0.04
# False Omission Rate                0.0  0.00    0.01  0.00  0.18    0.22
# Prevalence Threshold               0.0  0.09    0.00  0.33  0.36    0.13
# F1 Score                           1.0  0.99    0.99  0.81  0.63    0.61
# Matthews Correlation Coefficient   1.0  0.98    0.98  0.72  0.44    0.57
# False positive rate                0.0  0.01    0.00  0.24  0.21    0.01
# False Negative Rate                0.0  0.00    0.02  0.00  0.35    0.56

# %% [markdown]
# Test accuracy is 80%.

# %% [markdown]
# <a id='6'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     6 Save and load the model
#     </h2>
# </div>

# %%
model.save('rock_paper_scissors_saved.model')
# Out:
# 2021-08-06 00:58:57.383078: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: rock_paper_scissors_saved.model/assets
# INFO:tensorflow:Assets written to: rock_paper_scissors_saved.model/assets

# %%
model = load_model('rock_paper_scissors_saved.model')

# %%
y_train_predicted = model.predict(train_images)
y_test_predicted = model.predict(test_images)
# Out:
# 2021-08-06 00:58:58.264716: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.

# %%
num = 50
y_test_predicted[num]
print('predicted: ', np.argmax(y_test_predicted[num]))
print('truth: ', test_labels[num])

plt.imshow(test_images[num], cmap=plt.cm.binary)
plt.show()
# Out:
# predicted:  0
# truth:  tf.Tensor(0, shape=(), dtype=int64)

# %% [markdown]
# <a id='7'></a>
# <div class="alert alert-block alert-danger">
#    <h2>
#     7 References
#     </h2>
# </div>

# %% [markdown]
# https://www.youtube.com/watch?v=44U8jJxaNp8
#
# https://keras-team.github.io/keras-tuner/
